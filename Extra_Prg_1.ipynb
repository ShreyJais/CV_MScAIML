# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyJais/CV_MScAIML/blob/main/Extra_Prg_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow

# %%
#read image
img = cv.imread("/content/drive/MyDrive/Classroom/MSC(AI & ML)-Introduction to Research Methodology/Task_2.png")
#display image
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x1541>

# %%
#Using ImageIO
import imageio as iio

#Read an image
img = iio.imread("/content/drive/MyDrive/Classroom/Data engineering and knowledge representation MSc AIML/COVER.jpg")

#Write it in a new format
iio.imwrite("PngToJpg.jpg",img)
# Out:
# <ipython-input-81-af748676e573>:5: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = iio.imread("/content/drive/MyDrive/Classroom/Data engineering and knowledge representation MSc AIML/COVER.jpg")

# %%
#Using MatplotLib
# Python program to read image using matplotlib
##cv2 uses BGR color format
# Matplot uses RGB Color format


# importing matplotlib modules
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# Read Images
img = mpimg.imread('PngToJpg.jpg')

# Output Images
plt.imshow(img)

# %%
#Using PIL : PIL is the Python Imaging Library
#Python program to read image using PIL module

# importing PIL
#Python Imaging Library
from PIL import Image

# Read image
img = Image.open('PngToJpg.jpg')

# Output Images
#img.show(img)
display(img)

# prints format of image
print("Format:\t", img.format)

# prints mode of image
# Eg- RGB, RFBA, CMYK, BGRetc.
print("Mode of image:\t", img.mode)

# Prints the name of the file
print("Filename:\t", img.filename)

# Prints the size as a width and height tuple (in pixels)
print("Size:\t", img.size)

# Prints the width of the image (in pixels)
print("Width:\t", img.width)

# Prints the height of the image (in pixels)
print("Height:\t", img.height)

# Closing the image
img.close()
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x394>
# Format:	 JPEG
# Mode of image:	 RGB
# Filename:	 PngToJpg.jpg
# Size:	 (263, 394)
# Width:	 263
# Height:	 394

# %%
#Accessing pixel values
import cv2
import numpy as np

img = cv2.imread('/content/drive/MyDrive/Classroom/MSC(AI & ML)-Introduction to Research Methodology/Task_2.png')
pixel= img[100,100]
print (pixel)

# accessing only blue pixel
Blue = img[100,100,0] # if we specify 1 then we can access green pixel and 2 is for red
print ("Blue:\t", Blue)
Green = img[100,100,1]
print ("Green:\t", Green)
Red = img[100,100,2]
print ("Red:\t", Red)
#By default cv2 read image in BGR
# Out:
# [205 208 186]
# Blue:	 205
# Green:	 208
# Red:	 186

# %%
#image is store in matrix formate in diffrent modes(RGB, RFBA, CMYK)
img
# Out:
# array([[[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
#         ...,
#         [205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186]],
#
#        [[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
#         ...,
#         [205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186]],
#
#        [[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
#         ...,
#         [205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186]],
#
#        ...,
#
#        [[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
#         ...,
#         [205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186]],
#
#        [[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
#         ...,
#         [205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186]],
#
#        [[205, 208, 186],
#         [205, 208, 186],
#         [205, 208, 186],
# ...

# %%
#modify the pixel values
for i in range(800):
  img[i,i] = [255,255,255] #white = [B,G,R] = [255,255,255]
print(img[100,100])
cv2_imshow(img)
# Out:
# [255 255 255]
# <PIL.Image.Image image mode=RGB size=800x1541>

# %%
print (img.shape)
#If image is grayscale, tuple returned contains only number of rows and columns.
#the here 3 represent the chanales of the image whish is BGR
# Out:
# (1541, 800, 3)

# %%
print (img.size)
#Display Total number of pixelsa = 1541*800*3 (product of the shape)
# Out:
# 3698400

# %%
print (img.dtype)
# used to display the datatype
# Out:
# uint8

# %%
#Splitting and Merging Image Channels
b,g,r = cv2.split(img)
cv2_imshow(b)
cv2_imshow(g)
cv2_imshow(r)
img1 = cv2.merge((b,g,r))
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=L size=800x1541>
# <PIL.Image.Image image mode=L size=800x1541>
# <PIL.Image.Image image mode=L size=800x1541>
# <PIL.Image.Image image mode=RGB size=800x1541>

# %%
#make all the red pixels to zero
img[:,:,2] = 0
#In img all the vlaues of (3rd channel of index 2 which respond to red in BGR) is set to 0
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=800x1541>
