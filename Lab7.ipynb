# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyJais/CV_MScAIML/blob/main/Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## De-noising

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Loading the image

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread('/content/drive/MyDrive/Classroom/Data engineering and knowledge representation MSc AIML/1aad848b-3adc-4bcd-96f4-a0492d93d5c9.png',0)
plt.imshow(img,"gray")

# %% [markdown]
# ### Adding Salt and Pepper noise

# %%
import random
row , col = img.shape
number_of_pixels = random.randint(300, 10000)
for i in range(number_of_pixels):
    y_coord=random.randint(0, row - 1)
    x_coord=random.randint(0, col - 1)
    img[y_coord][x_coord] = 255
number_of_pixels = random.randint(300 , 10000)
for i in range(number_of_pixels):
    y_coord=random.randint(0, row - 1)
    x_coord=random.randint(0, col - 1)
    img[y_coord][x_coord] = 0
plt.imshow(img,"gray")

# %% [markdown]
# ### de-noising using min filter

# %%
from scipy.ndimage import minimum_filter
min=minimum_filter(img, size=3)
plt.imshow(min,"gray")

# %% [markdown]
# ### de-noising using max filter

# %%
from scipy.ndimage import maximum_filter
max=maximum_filter(img, size=3)
plt.imshow(max,"gray")

# %% [markdown]
# ### de-noising using median filter

# %%
from scipy.ndimage import median_filter
mid=median_filter(img, size=3)
plt.imshow(mid,"gray")
